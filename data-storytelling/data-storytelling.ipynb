# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# fake data
months = ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun", "Jul", "Ago", "Set", "Out", "Nov", "Dez"]
sales_a = [180, 172, 190, 173, 161, 197, 202, 187, 183, 250, 187, 172]
sales_b = [180, 170, 184, 169, 159, 187, 192, 180, 169, 171, 140, 124]

# %%
plt.rcParams['font.family'] = 'Futura'

blue = "#025F9D"
grey = "#9E9E9E"
grey_txt = "#515151"

# %%
fig,ax = plt.subplots(figsize=(10,10),dpi=90)

fig.set(tight_layout=True)

ax.plot(sales_a,
        color=blue,
        zorder=4)

ax.plot(sales_b,
        color=grey,
        zorder=2)

ax.scatter(x=range(0,len(sales_a)),
           y=sales_a,
           color=blue,
           zorder=3)

ax.scatter(x=range(0,len(sales_b)),
           y=sales_b,
           color=grey,
           zorder=1)

ax.scatter(x=range(0,len(sales_a))[9:10],
           y=sales_a[9:10],
           color='crimson',
           s=50,
           zorder=5)

ax.spines[['top','right']].set_visible(False)
# ax.spines[['bottom','left']].set_color(grey)

ax.set_xticks(ticks=range(12))
ax.set_xticklabels(labels=months)

ax.set_ylim(0,300)

ax.set_ylabel("Revenues in $USD (thousands)",
              fontsize=12
              )

ax.annotate(xy=(sales_a.index(max(sales_a)) + 0.2, max(sales_a) + 0.2),
            text=f"Max revenue: ${max(sales_a):.2f}",
            color='crimson',
            fontweight='medium',
            fontsize=12
            )
fig.text(x=0.01,
        y=1.05,
        s="Title of this chart",
        fontsize=30,
        fontweight='bold'
        )

fig.text(x=0.01,
        y=1.025,
        s=" Subtitle",
        fontsize=15,
        fontweight='light'
        )

fig.text(x=0.02,
        y=-0.01,
        s="Source: don't forget to add sources",
        fontsize=9,
        fontweight='regular',
        color=grey_txt
        );
